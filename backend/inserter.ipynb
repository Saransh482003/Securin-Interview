# %%
from models import *
import sqlite3
import pandas as pd

recipes = pd.read_json("US_recipes_null.json", orient="index")
recipes
# Out:
#            Contient Country_State                      cuisine  \
# 0     North America            US             Southern Recipes
# 1     North America            US             Southern Recipes
# 2     North America            US             Southern Recipes
# 3     North America            US             Southern Recipes
# 4     North America            US             Southern Recipes
# ...             ...           ...                          ...
# 8446  North America            US  Amish and Mennonite Recipes
# 8447  North America            US  Amish and Mennonite Recipes
# 8448  North America            US  Amish and Mennonite Recipes
# 8449  North America            US  Amish and Mennonite Recipes
# 8450  North America            US  Amish and Mennonite Recipes
#
#                                                   title  \
# 0                                      Sweet Potato Pie
# 1                          Fresh Southern Peach Cobbler
# ...

# %%
data = pd.read_json("US_recipes_null.json", orient="index")
data.fillna("NULL", inplace=True)
# Out:
# C:\Users\Saransh\AppData\Local\Temp\ipykernel_19184\371834232.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NULL' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.fillna("NULL", inplace=True)

# %%
from models import Recipes

# %%
Recipes.query.all()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Recipies.query.all()
#
# File e:\Securin Interview\env\Lib\site-packages\flask_sqlalchemy\model.py:23, in _QueryProperty.__get__(self, obj, cls)
#      21 def __get__(self, obj: Model | None, cls: type[Model]) -> Query:
#      22     return cls.query_class(
# ---> 23         cls, session=cls.__fsa__.session()  # type: ignore[arg-type]
#      24     )
#
# File e:\Securin Interview\env\Lib\site-packages\sqlalchemy\orm\scoping.py:220, in scoped_session.__call__(self, **kw)
#     218         self.registry.set(sess)
#     219 else:
# --> 220     sess = self.registry()
#     221 if not self._support_async and sess._is_asyncio:
#     222     warn_deprecated(
#     223         "Using `scoped_session` with asyncio is deprecated and "
#     224         "will raise an error in a future version. "
# ...

# %%
import pandas as pd

# %%
data = pd.read_json("../data/US_recipes_null.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = pd.read_json("../data/US_recipes_null.json")
#
# NameError: name 'pd' is not defined
